# %% [markdown]
# ## Nakuru Flood Vulnerability tool

# %%
import geopandas as gpd
import rasterio
import pandas as pd
from rasterio.plot import show


data = pd.read_csv("/table_2014_adult_hiv_prevalence_rate_by_county.csv")
print(data.shape())
